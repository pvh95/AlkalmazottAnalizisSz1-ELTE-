% %% [markdown]
% ## A május 11-ei ZH megoldasa

% %%
%% 1.feladat
%% Helyes abra pl n=11-re
A0WA6S_1(11)

% %%
%% Hibauzenet visszaadasa pl n = 8-ra
A0WA6S_1(8)
% Out:
% A vektor hossza nem megfelelo!

% %%
%% 2.feladat
A0WA6S_2
% Out:
% N =
%
%    -3.00000    1.00000    0.00000    0.00000    0.00000    0.00000    0.00000
%    -2.00000   -4.00000   -5.00000    0.00000    0.00000    0.00000    0.00000
%     0.00000    4.00000    4.00000    3.00000    0.00000    0.00000    0.00000
%     2.00000   -4.00000   -4.00000   -2.00000   -1.00000    0.00000    0.00000
%     3.00000    7.00000   11.00000    5.00000    1.40000    0.40000    0.00000
%     5.00000   17.00000    5.00000   -2.00000   -1.40000   -0.40000   -0.10000

% %%
%% 3.feladat
A0WA6S_3(1e-2)
% Out:
% A feladat megoldasahoz 25 reszintervallumra volt szukseg a megadott TOL ertek mellett az altalunk valsztott fix [1, 9] intervallumon.

% %%
%% 4.feladat
A0WA6S_4(@(x)(x.^5),5)
% Out:
% Az egyre finomodo h melletti kozelito derivalt ertekei rendre:
%    6.00000000000000e+02
%    5.99999999999454e+02
%    6.00000112171983e+02
%    5.99357008468360e+02
%    0.00000000000000e+00
%   -1.36424205265939e+08
%    1.81898940354586e+12
%   -9.09494701772928e+15
%   -9.09494701772928e+19
